# %% [markdown]
# # Medical Image Registration

# %% [markdown]
# ### 1. Import Packages and Functions

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %% [markdown]
# ### 2. Rotate Image Function
#
# This function is used to rotate the image by a given angle.

# %%
def rotate_image(image, angle):
    image_center = tuple(np.array(image.shape[1::-1]) / 2)
    rot_mat = cv2.getRotationMatrix2D(image_center, angle, 1.0)
    result = cv2.warpAffine(image, rot_mat, image.shape[1::-1], flags=cv2.INTER_LINEAR)
    return result

# %% [markdown]
# ### 3. SIFT Function

# %%
def sift(image):
  
    # read the image
    img1=cv2.imread(image)
  
    # show the image
    cv2.imshow("Original Image",img1)
  
    # create the second image by rotating the original image
    img2=rotate_image(img1,34)


    # convert images to grayscale
    img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
    img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
    
    # create SIFT object
    sift = cv2.xfeatures2d.SIFT_create()
  
    # detect SIFT features in both images
    keypoints_1, descriptors_1 = sift.detectAndCompute(img1,None)
    keypoints_2, descriptors_2 = sift.detectAndCompute(img2,None)
  
    
    #Now that we have keypoints and descriptors of both images, let's make a matcher to match the descriptors:

    # create feature matcher
    bf = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)
  

    # match descriptors of both images
    matches = bf.match(descriptors_1,descriptors_2)
      
    #Sort the matches by distance and draw the first 50 matches:
    # sort matches by distance
    matches = sorted(matches, key = lambda x:x.distance)
  
    # draw first 50 matches
    matched_img = cv2.drawMatches(img1, keypoints_1, img2, keypoints_2, matches[:50], img2, flags=2)
      
    #Finally, showing and saving the image:
    # show the image
    cv2.imshow("Output",matched_img)
  

    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %% [markdown]
# ### 4. Call SIFT Function on Images

# %%
sift("thumbnail.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=200x184 at 0x7F23E5253E50>
# <PIL.Image.Image image mode=RGB size=400x184 at 0x7F23E51E3C10>

# %%
sift("thumbnail1.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=200x138 at 0x7F23E51EF510>
# <PIL.Image.Image image mode=RGB size=400x138 at 0x7F23E51EF510>

# %%
sift("thumbnail2.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=200x174 at 0x7F23F1E47490>
# <PIL.Image.Image image mode=RGB size=400x174 at 0x7F23F1E47F90>

# %%
sift("thumbnail3.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=185x200 at 0x7F23E51EFA10>
# <PIL.Image.Image image mode=RGB size=370x200 at 0x7F23F7E7FFD0>

# %%
sift("thumbnail4.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=185x200 at 0x7F23E51EFB90>
# <PIL.Image.Image image mode=RGB size=370x200 at 0x7F23F1E472D0>

# %%
sift("thumbnail5.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=200x121 at 0x7F23E51F7550>
# <PIL.Image.Image image mode=RGB size=400x121 at 0x7F23E51F7590>

# %%
sift("thumbnail6.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=200x175 at 0x7F23E51F7C10>
# <PIL.Image.Image image mode=RGB size=400x175 at 0x7F23E51F7E10>

# %%
sift("thumbnail7.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=200x108 at 0x7F23E5202550>
# <PIL.Image.Image image mode=RGB size=400x108 at 0x7F23E5202590>

# %%
sift("thumbnail8.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=200x134 at 0x7F23E5202E90>
# <PIL.Image.Image image mode=RGB size=400x134 at 0x7F23E52029D0>

# %%
sift("thumbnail9.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=200x190 at 0x7F23E5203810>
# <PIL.Image.Image image mode=RGB size=400x190 at 0x7F23E5203850>
